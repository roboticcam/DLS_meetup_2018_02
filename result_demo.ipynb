# %% [markdown]
# ## Batch Norm apply on Dog&Cat dataset

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# %matplotlib inline

from IPython.display import Image
Image(filename='bn_iteration.png')

# %%
from IPython.display import Image
Image(filename='bn_time.png')

# %% [markdown]
# ### Generating Shakespeare like sentence using Recurrent Neural Network

# %%
from IPython.display import Image
Image(filename='ln_time.png')

# %%
from IPython.display import Image
Image(filename='ln_iteration.png')
